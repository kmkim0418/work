# %% [markdown]
# <a href="https://colab.research.google.com/github/kmkim0418/work/blob/main/0320.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

url = "https://daily.siwonschool.com/"

response = requests.get(url)

if response.status_code == 200:
    print(response.text)
else:
    print("Request failed with status code:", response.status_code)
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=1200">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#     <meta name="keyword" content="시원스쿨영어진짜학습지,시원스쿨진짜말하기학습지,성인영어학습지,성인학습지,학습지,외국어학습지,일본어학습지,성인일본어,일본어공부,일본여행공부,유럽여행공부,독일어학습지,러시아어학습지,프랑스어학습지,중국어학습지,시원스쿨학습지,영어회화학습지,성인눈높이영어,성인용학습지,성인영어회화학습지,시원스쿨영어학습지,영어공부학습지,영어학습지추천,진짜말하기학습지,성인영어학습지추천">
#     <meta name="description" content="하루 1장, 하루 10분 나의 언어 실력이 변화하는 습관 형성">
#     <meta property="og:keywords" content="시원스쿨영어진짜학습지,시원스쿨진짜말하기학습지,성인영어학습지,성인학습지,학습지,외국어학습지,일본어학습지,성인일본어,일본어공부,일본여행공부,유럽여행공부,독일어학습지,러시아어학습지,프랑스어학습지,중국어학습지,시원스쿨학습지,영어회화학습지,성인눈높이영어,성인용학습지,성인영어회화학습지,시원스쿨영어학습지,영어공부학습지,영어학습지추천,진짜말하기학습지,성인영어학습지추천">
#     <meta property="og:description" content="하루 1장, 하루 10분 나의 언어 실력이 변화하는 습관 형성">
#     <meta property="og:type" content="website">
#     <meta property="og:url" content="//daily.siwonschool.com">
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = "https://daily.siwonschool.com/"

response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    elements_with_text_jinjja = soup.find_all(text="진짜학습지")

    for element in elements_with_text_jinjja:
        print(element)
else:
    print("Request failed with status code:", response.status_code)
# Out:
# 진짜학습지
# 진짜학습지
# <ipython-input-9-ef55ed3d8c3b>:10: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   elements_with_text_jinjja = soup.find_all(text="진짜학습지")
